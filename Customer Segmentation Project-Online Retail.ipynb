# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"D:\Road to Data Science\PROJECTS\OnlineRetail (3).csv",encoding='ISO-8859-1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# #### Reading first 10 records of dataset

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %% [markdown]
# #### Information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
#### Null value

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Invoice Date']=pd.to_datetime(df['InvoiceDate'])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df['Month'] = df['Invoice Date'].dt.to_period('M')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df.drop(columns=['InvoiceDate'],inplace=True)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  CustomerID         Country        Invoice Date    Month
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# #### Total Sales By country

# %%
total_sales_by_country=df.groupby('Country')['UnitPrice'].sum().sort_values(ascending=False)
total_sales_by_country
# Out:
# Country
# United Kingdom    1165878.034
# France              42825.230
# EIRE                38209.260
# Germany             37633.440
# Singapore           25108.890
#                      ...
# Brazil                142.600
# Lithuania              99.440
# Czech Republic         88.150
# Bahrain                78.950
# Saudi Arabia           24.110
# Name: UnitPrice, Length: 37, dtype: float64

# %%
plt.figure(figsize=(12, 6))
total_sales_by_country.plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# #### Most purchased products

# %%
df['Description'].value_counts().head(10)
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2058
# REGENCY CAKESTAND 3 TIER              1894
# JUMBO BAG RED RETROSPOT               1659
# PARTY BUNTING                         1409
# ASSORTED COLOUR BIRD ORNAMENT         1405
# LUNCH BAG RED RETROSPOT               1345
# SET OF 3 CAKE TINS PANTRY DESIGN      1224
# POSTAGE                               1196
# LUNCH BAG  BLACK SKULL.               1099
# PACK OF 72 RETROSPOT CAKE CASES       1062
# Name: Description, dtype: int64

# %%
plt.pie(df['Description'].value_counts().head(10),labels=df['Description'].value_counts().head(10).index,autopct='%.2f',pctdistance=0.8)
# Out:
# ([<matplotlib.patches.Wedge at 0x25cdb1c01d0>,
# ...
#  [Text(0.9902433632528264, 0.4789760761601055, 'WHITE HANGING HEART T-LIGHT HOLDER'),
#   Text(0.27761979467224707, 1.0643905531364601, 'REGENCY CAKESTAND 3 TIER'),
#   Text(-0.5490961688544569, 0.953149199941624, 'JUMBO BAG RED RETROSPOT'),
#   Text(-1.0229420000363634, 0.4044621917579009, 'PARTY BUNTING'),
#   Text(-1.068605286810537, -0.26092669660379797, 'ASSORTED COLOUR BIRD ORNAMENT'),
#   Text(-0.7329843102152163, -0.8202036338485241, 'LUNCH BAG RED RETROSPOT'),
#   Text(-0.18276001883770845, -1.0847113788996778, 'SET OF 3 CAKE TINS PANTRY DESIGN '),
#   Text(0.39042923468335583, -1.028379799833004, 'POSTAGE'),
#   Text(0.8373803947493788, -0.7132980264162903, 'LUNCH BAG  BLACK SKULL.'),
#   Text(1.0704069673038559, -0.25343426040565664, 'PACK OF 72 RETROSPOT CAKE CASES')],
#  [Text(0.720176991456601, 0.3483462372073495, '14.34'),
#   Text(0.20190530521617966, 0.77410222046288, '13.20'),
# ...

# %% [markdown]
# #### Monthly sales trends

# %%
monthly_sales = df.groupby('Month')['UnitPrice'].sum()
monthly_sales
# Out:
# Month
# 2010-12     84772.430
# 2011-01     72470.730
# 2011-02     66935.550
# 2011-03     95477.280
# 2011-04     90654.871
#               ...
# 2011-08     87577.060
# 2011-09    125109.692
# 2011-10    184790.120
# 2011-11    192109.700
# 2011-12     49482.060
# Freq: M, Name: UnitPrice, Length: 13, dtype: float64

# %%
monthly_sales.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_sales=df.groupby('Month')['UnitPrice'].sum()

# %%
monthly_sales
# Out:
# Month
# 2010-12     84772.430
# 2011-01     72470.730
# 2011-02     66935.550
# 2011-03     95477.280
# 2011-04     90654.871
#               ...
# 2011-08     87577.060
# 2011-09    125109.692
# 2011-10    184790.120
# 2011-11    192109.700
# 2011-12     49482.060
# Freq: M, Name: UnitPrice, Length: 13, dtype: float64

# %%
import datetime as dt

today = df['Invoice Date'].max()
rfm = df.groupby('CustomerID').agg({
    'Invoice Date': lambda x: (today - x.max()).days,
    'InvoiceNo': 'count',
    'UnitPrice': 'sum'
})
rfm.columns = ['Recency', 'Frequency', 'Monetary']

# %%
rfm
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         325          2      2.08
# 12347.0           1        182    481.21
# 12348.0          74         31    178.71
# 12349.0          18         73    605.10
# 12350.0         309         17     65.30
# ...             ...        ...       ...
# 18280.0         277         10     47.65
# 18281.0         180          7     39.36
# 18282.0           7         13     62.68
# 18283.0           3        721   1174.33
# 18287.0          42         70    104.55
#
# [4372 rows x 3 columns]

# %%
rfm.groupby('CustomerID')['Frequency'].sum()
# Out:
# CustomerID
# 12346.0      2
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
#           ...
# 18280.0     10
# 18281.0      7
# 18282.0     13
# 18283.0    721
# 18287.0     70
# Name: Frequency, Length: 4372, dtype: int64

# %%
rfm.groupby('CustomerID')['Monetary'].sum()
# Out:
# CustomerID
# 12346.0       2.08
# 12347.0     481.21
# 12348.0     178.71
# 12349.0     605.10
# 12350.0      65.30
#             ...
# 18280.0      47.65
# 18281.0      39.36
# 18282.0      62.68
# 18283.0    1174.33
# 18287.0     104.55
# Name: Monetary, Length: 4372, dtype: float64

# %% [markdown]
# ## K-Means Clustering

# %%
# Perform K-Means clustering for customer segmentation
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(rfm)
individual_clustering_score=[]
for i in range(1,10):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(rfm_scaled)
    individual_clustering_score.append(kmeans.inertia_)
# Out:
# C:\Users\souvi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\souvi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\souvi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,10),individual_clustering_score)

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(rfm_scaled)

rfm['Cluster'] = kmeans.labels_

rfm
# Out:
# C:\Users\souvi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#             Recency  Frequency  Monetary  Cluster
# CustomerID
# 12346.0         325          2      2.08        2
# 12347.0           1        182    481.21        0
# 12348.0          74         31    178.71        0
# 12349.0          18         73    605.10        0
# 12350.0         309         17     65.30        2
# ...             ...        ...       ...      ...
# 18280.0         277         10     47.65        2
# 18281.0         180          7     39.36        2
# 18282.0           7         13     62.68        0
# 18283.0           3        721   1174.33        0
# 18287.0          42         70    104.55        0
#
# [4372 rows x 4 columns]

# %%
# Visualize customer segments
sns.scatterplot(x='Recency', y='Frequency', hue='Cluster', data=rfm)
plt.title('Customer Segmentation')
plt.show()

# %%
kmeans.cluster_centers_
# Out:
# array([[-5.12331660e-01,  6.28674271e-02,  1.09290677e-02],
#        [-5.15158773e-01,  1.44342187e+01,  2.16719512e+01],
#        [ 1.54832502e+00, -2.82538139e-01, -1.72519910e-01]])

# %%
from sklearn.metrics import silhouette_score
silhouette_score(rfm,kmeans.labels_)
# Out:
# 0.09019599204317656

# %% [markdown]
# ## Hierarchical Clustering

# %%
import scipy.cluster.hierarchy as sch

plt.figure(figsize=(10,6))
dendogram=sch.dendrogram(sch.linkage(rfm,method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster=AgglomerativeClustering(n_clusters=2,affinity='euclidean',linkage='ward')
cluster_labels = cluster.fit_predict(rfm)
cluster_labels
# Out:
# C:\Users\souvi\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import silhouette_score
silhouette_score(rfm,cluster_labels)
# Out:
# 0.983180220871163

# %%
rfm['Agglo_Clusters']=cluster_labels
rfm
# Out:
#             Recency  Frequency  Monetary  Cluster  Agglo_Clusters
# CustomerID
# 12346.0         325          2      2.08        2               1
# 12347.0           1        182    481.21        0               1
# 12348.0          74         31    178.71        0               1
# 12349.0          18         73    605.10        0               1
# 12350.0         309         17     65.30        2               1
# ...             ...        ...       ...      ...             ...
# 18280.0         277         10     47.65        2               1
# 18281.0         180          7     39.36        2               1
# 18282.0           7         13     62.68        0               1
# 18283.0           3        721   1174.33        0               1
# 18287.0          42         70    104.55        0               1
#
# [4372 rows x 5 columns]

# %%
sns.scatterplot(x='Recency', y='Frequency', hue='Agglo_Clusters', data=rfm)
plt.title('Customer Segmentation')
plt.show()

# %% [markdown]
# ## Apriori Algorithm

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
pd.set_option('display.max_rows',10)
pd.set_option('display.max_columns',10)

# %%
df=pd.read_csv(r"D:\Road to Data Science\PROJECTS\OnlineRetail (3).csv",encoding='ISO-8859-1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df['Description']=df['Description'].str.strip()
df.dropna(axis=0,subset=['InvoiceNo'],inplace=True)
df['InvoiceNo']=df['InvoiceNo'].astype(str)
df=df[~df['InvoiceNo'].str.contains('C')]
df.shape
# Out:
# (532621, 8)

# %%
basket=(df[df['Country']=='France'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).
        set_index(['InvoiceNo']))

# %%
def encode_units(x):
    if x<=0:
        return 0
    if x>=1:
        return 1
basket_set=basket.applymap(encode_units)
basket_set.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  ...  ZINC FOLKART SLEIGH BELLS  \
# ...

# %%
frequent_items=apriori(basket_set,min_support=0.07,use_colnames=True)
rules=association_rules(frequent_items,metric='lift',min_threshold=1)
rules.head()
# Out:
# C:\Users\souvi\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                     antecedents                   consequents  \
# 0   (ALARM CLOCK BAKELIKE PINK)  (ALARM CLOCK BAKELIKE GREEN)
# 1  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE PINK)
# 2    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)
# 3  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)
# 4                     (POSTAGE)  (ALARM CLOCK BAKELIKE GREEN)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.102041            0.096939  0.073980    0.725000  7.478947
# 1            0.096939            0.102041  0.073980    0.763158  7.478947
# 2            0.094388            0.096939  0.079082    0.837838  8.642959
# ...

# %%
rules[(rules['lift']>=6) & (rules['confidence']>=0.8)].head(10)
# Out:
#                                   antecedents  \
# 2                  (ALARM CLOCK BAKELIKE RED)
# 3                (ALARM CLOCK BAKELIKE GREEN)
# 75            (SET/6 RED SPOTTY PAPER PLATES)
# 76              (SET/6 RED SPOTTY PAPER CUPS)
# 77            (SET/6 RED SPOTTY PAPER PLATES)
# 78        (ALARM CLOCK BAKELIKE RED, POSTAGE)
# 80      (POSTAGE, ALARM CLOCK BAKELIKE GREEN)
# 114    (SET/6 RED SPOTTY PAPER CUPS, POSTAGE)
# 116  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
# 119           (SET/6 RED SPOTTY PAPER PLATES)
#
#                                 consequents  antecedent support  \
# 2              (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 3                (ALARM CLOCK BAKELIKE RED)            0.096939
# 75     (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 76          (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 77            (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 78             (ALARM CLOCK BAKELIKE GREEN)            0.086735
# ...
